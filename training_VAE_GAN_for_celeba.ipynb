# %%
# Import dependencies
import tensorflow as tf
from tensorflow import keras

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pathlib
import PIL
import PIL.Image
import cv2

from tqdm import tqdm

# %%
# Lets check your GPU
if tf.config.list_logical_devices('GPU') != []:
    print("LET'S DO THISS!!! :DDDD")
else: 
    print("Oh dude... D:")
# Out:
# LET'S DO THISS!!! :DDDD

# %%
'''

Lets define some dir to save iamges.

'''

from pathlib import Path

IMAGES_PATH = Path() / "images" / "generative"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
path = "./img_align_celeba"
data_dir = pathlib.Path(path)

# Lets check quantity
image_count = len(list(data_dir.glob('*.jpg')))
print('We have', image_count, 'images.')
# Out:
# We have 202599 images.

# %%
# Get all paths
all_paths = [str(x) for x in list(data_dir.glob('*.jpg'))]

# %%
train_path = all_paths[:int(image_count * 0.8)]
val_path = all_paths[int(image_count * 0.8): int(image_count * 0.9)]
test_path = all_paths[int(image_count * 0.9):]

# %%
# Sanity check!
PIL.Image.open(train_path[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=178x218>

# %%
# Instanciate tf datasets
ds_train_path = tf.data.Dataset.from_tensor_slices(train_path)
ds_val_path = tf.data.Dataset.from_tensor_slices(val_path)
ds_test_path = tf.data.Dataset.from_tensor_slices(test_path)

# %%
'''

Open all images and resize.

'''

def open_image(x):
    return tf.ensure_shape(tf.image.decode_image(tf.io.read_file(x)), [218, 178, 3])

def resize_image(x, n_outputs=1):
    if n_outputs == 2:
        return (tf.image.resize(x, [128, 128]) / 255., tf.image.resize(x, [128, 128]) / 255.)
    return tf.image.resize(x, [128, 128]) / 255.

ds_train = ds_train_path.map(
    lambda x: resize_image(open_image(x))
)

ds_val = ds_val_path.map(
    lambda x: resize_image(open_image(x))
)

ds_test = ds_test_path.map(
    lambda x: resize_image(open_image(x))
)

# %%
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        mean, log_var = inputs
        return tf.random.normal(tf.shape(log_var)) * tf.exp(log_var / 2) + mean

# %%
from functools import partial

DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, strides=1,
                        padding="same", kernel_initializer="he_normal",
                        use_bias=False)

DefaultDeConv2D = partial(tf.keras.layers.Conv2DTranspose, kernel_size=3, strides=2,
                          padding="same", kernel_initializer="he_normal",
                          use_bias=False)

class ResidualUnit(tf.keras.layers.Layer):
    def __init__(self, filters, strides=1, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = tf.keras.activations.get(activation)
        self.main_layers = [
            DefaultConv2D(filters, strides=strides),
            tf.keras.layers.BatchNormalization(),
            self.activation,
            DefaultConv2D(filters),
            tf.keras.layers.BatchNormalization()
        ]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConv2D(filters, kernel_size=1, strides=strides),
                tf.keras.layers.BatchNormalization()
            ]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)
    
class ResidualDeConvUnit(tf.keras.layers.Layer):
    def __init__(self, filters, strides=1, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = tf.keras.activations.get(activation)
        self.main_layers = [
            DefaultDeConv2D(filters, strides=strides),
            tf.keras.layers.BatchNormalization(),
            self.activation,
            DefaultConv2D(filters),
            tf.keras.layers.BatchNormalization()
        ]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultDeConv2D(filters, kernel_size=1, strides=strides),
                tf.keras.layers.BatchNormalization()
            ]
        
    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
codings_size = 1024
inputs = tf.keras.layers.Input(shape=[128, 128, 3])
# Z = keras.layers.Reshape([128, 128, 1])(inputs)
Z = DefaultConv2D(64, kernel_size=3, strides=2)(inputs)
Z = keras.layers.Activation("relu")(Z)
Z = keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(Z)

prev_filters = 64
for filters in [64] * 1 + [128] * 2 + [256] * 2 + [512] * 1:
    strides = 1 if filters == prev_filters else 2
    Z = ResidualUnit(filters, strides=strides)(Z)
    prev_filters = filters

Z = keras.layers.GlobalAvgPool2D()(Z)
Z = keras.layers.Flatten()(Z)

codings_mean = tf.keras.layers.Dense(codings_size)(Z)  # μ
codings_log_var = tf.keras.layers.Dense(codings_size)(Z)  # γ
codings = Sampling()([codings_mean, codings_log_var])
variational_encoder = tf.keras.Model(
    inputs=[inputs], outputs=[codings_mean, codings_log_var, codings])

# %%
variational_encoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 64, 64, 64)   1728        ['input_1[0][0]']
#
#  activation (Activation)        (None, 64, 64, 64)   0           ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['activation[0][0]']
#
#  residual_unit (ResidualUnit)   (None, 32, 32, 64)   74240       ['max_pooling2d[0][0]']
#
#  residual_unit_1 (ResidualUnit)  (None, 16, 16, 128)  230912     ['residual_unit[0][0]']
#
#  residual_unit_2 (ResidualUnit)  (None, 16, 16, 128)  295936     ['residual_unit_1[0][0]']
#
#  residual_unit_3 (ResidualUnit)  (None, 8, 8, 256)   920576      ['residual_unit_2[0][0]']
#
#  residual_unit_4 (ResidualUnit)  (None, 8, 8, 256)   1181696     ['residual_unit_3[0][0]']
#
#  residual_unit_5 (ResidualUnit)  (None, 4, 4, 512)   3676160     ['residual_unit_4[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['residual_unit_5[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 512)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1024)         525312      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1024)         525312      ['flatten[0][0]']
#
#  sampling (Sampling)            (None, 1024)         0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
# ==================================================================================================
# Total params: 7,431,872
# Trainable params: 7,424,704
# Non-trainable params: 7,168
# __________________________________________________________________________________________________

# %%
decoder_inputs = tf.keras.layers.Input(shape=[codings_size])
x = keras.layers.Dense(4 * 4 * (512))(decoder_inputs)
x = keras.layers.Reshape((4, 4, 512))(x)
x = keras.layers.Conv2DTranspose(512, 3, padding='same', activation='relu')(x)
x = keras.layers.UpSampling2D(2)(x)
prev_filters = 512
for filters in ([64] * 1 + [128] * 2 + [256] * 2 + [512] * 1)[::-1]:
    strides = 1 if filters == prev_filters else 2
    x = ResidualDeConvUnit(filters, strides=strides)(x)
    prev_filters = filters

x = keras.layers.Conv2DTranspose(32, 3, padding='same', activation='relu')(x)
x = keras.layers.UpSampling2D(2)(x)
x = keras.layers.Conv2DTranspose(3, 3, padding='same', activation='sigmoid')(x)
outputs = keras.layers.Reshape([128, 128, 3])(x)
variational_decoder = tf.keras.Model(inputs=[decoder_inputs], outputs=[outputs])

# %%
variational_decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1024)]            0
#
#  dense_2 (Dense)             (None, 8192)              8396800
#
#  reshape (Reshape)           (None, 4, 4, 512)         0
#
#  conv2d_transpose (Conv2DTra  (None, 4, 4, 512)        2359808
#  nspose)
#
#  up_sampling2d (UpSampling2D  (None, 8, 8, 512)        0
#  )
#
#  residual_de_conv_unit (Resi  (None, 8, 8, 512)        4722688
#  dualDeConvUnit)
#
#  residual_de_conv_unit_1 (Re  (None, 16, 16, 256)      1903616
#  sidualDeConvUnit)
#
#  residual_de_conv_unit_2 (Re  (None, 16, 16, 256)      1181696
#  sidualDeConvUnit)
#
#  residual_de_conv_unit_3 (Re  (None, 32, 32, 128)      476672
#  sidualDeConvUnit)
#
#  residual_de_conv_unit_4 (Re  (None, 32, 32, 128)      295936
#  sidualDeConvUnit)
#
#  residual_de_conv_unit_5 (Re  (None, 64, 64, 64)       119552
#  sidualDeConvUnit)
#
#  conv2d_transpose_10 (Conv2D  (None, 64, 64, 32)       18464
#  Transpose)
#
#  up_sampling2d_1 (UpSampling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_transpose_11 (Conv2D  (None, 128, 128, 3)      867
#  Transpose)
#
#  reshape_1 (Reshape)         (None, 128, 128, 3)       0
#
# =================================================================
# Total params: 19,476,099
# Trainable params: 19,469,827
# Non-trainable params: 6,272
# _________________________________________________________________

# %%
_, _, codings = variational_encoder(inputs)
reconstructions = variational_decoder(codings)
variational_ae = tf.keras.Model(inputs=[inputs], outputs=[reconstructions])

# %%
latent_loss = -0.5 * tf.reduce_sum(
    1 + codings_log_var - tf.exp(codings_log_var) - tf.square(codings_mean),
    axis=-1)
variational_ae.add_loss(tf.reduce_mean(latent_loss) / (128.0 * 128.0))

# %%
generator = variational_decoder

def build_discriminator(input_shape):
    inputs = keras.layers.Input(shape=input_shape)
    Z = keras.layers.Conv2D(64, kernel_size=3, strides=1, padding="same")(inputs)
    Z = keras.layers.LeakyReLU(0.2)(Z)

    prev_filters = 64
    for filters in [64] * 1 + [128] * 2 + [256] * 2 + [512] * 1:
        strides = 1 if filters == prev_filters else 2
        Z = ResidualUnit(filters, strides=strides)(Z)
        prev_filters = filters

    Z = keras.layers.GlobalAvgPool2D()(Z)
    Z = keras.layers.Flatten()(Z)
    Z = keras.layers.Dropout(0.5)(Z)
    Z = keras.layers.Dense(256, activation='relu')(Z)
    Z = keras.layers.Dropout(0.5)(Z)
    Z = keras.layers.Dense(128, activation='relu')(Z)
    Z = keras.layers.Dropout(0.5)(Z)
    Z = keras.layers.Dense(64, activation='relu')(Z)
    Z = keras.layers.Dropout(0.5)(Z)
    Z = keras.layers.Dense(32, activation='relu')(Z)
    Z = keras.layers.Dense(1, activation='sigmoid')(Z)  # Assuming binary classification (real or fake)
    model = keras.Model(inputs=[inputs], outputs=[Z])
    return model

discriminator = build_discriminator(input_shape=[128, 128, 3])
gan = keras.Sequential([generator, discriminator])

discriminator.summary(), gan.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_22 (Conv2D)          (None, 128, 128, 64)      1792
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 64)      0
#
#  residual_unit_6 (ResidualUn  (None, 128, 128, 64)     74240
#  it)
#
#  residual_unit_7 (ResidualUn  (None, 64, 64, 128)      230912
#  it)
#
#  residual_unit_8 (ResidualUn  (None, 64, 64, 128)      295936
#  it)
#
#  residual_unit_9 (ResidualUn  (None, 32, 32, 256)      920576
#  it)
#
#  residual_unit_10 (ResidualU  (None, 32, 32, 256)      1181696
#  nit)
#
#  residual_unit_11 (ResidualU  (None, 16, 16, 512)      3676160
#  nit)
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 6,555,905
# Trainable params: 6,548,737
# Non-trainable params: 7,168
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, 128, 128, 3)       19476099
#
#  model_3 (Functional)        (None, 1)                 6555905
#
# =================================================================
# Total params: 26,032,004
# Trainable params: 26,018,564
# Non-trainable params: 13,440
# _________________________________________________________________
# (None, None)

# %%
from IPython.display import clear_output

# estilo
plt.style.use('dark_background')
plt.rcParams['axes.facecolor'] = '#26262e' 
# colors [#482790,#1AD59E]
# background 'dark_background'

# Set random seed 42
np.random.seed(42)

def plot_multiple_images(images, n_cols=None, k=1):
    n_cols = n_cols or len(images)
    n_rows = (len(images) - 1) // n_cols + 1
    if images.shape[-1] == 1:
        images = images.squeeze(axis=-1)
    plt.figure(figsize=(n_cols * k, n_rows * k))
    for index, image in enumerate(images):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(image, cmap="binary")
        # clear_output()
        plt.axis("off")
        
def plot_losses(history):
    colors=['#482790','#417EB1','#1AD59E','#2687A7','#9760C6', '#FFD166']
    epochs = np.array(list(range(1, len(history['loss_reconstruction']) + 1))) * 10
    
    plt.figure(figsize=(6, 6))
    
    plt.plot(epochs, history['loss_reconstruction'], color=colors[0], label='Loss Reconstruction')
    plt.plot(epochs, history['loss_sobel'], color=colors[1], label='Loss Sobel')
    plt.plot(epochs, history['loss_dkl'], color=colors[2], label='Loss DKL')
    plt.plot(epochs, history['loss_discriminator'], color=colors[3], label='Loss Discriminator')
    plt.plot(epochs, history['loss_gan'], color=colors[4], label='Loss Generator')    
    plt.plot(epochs, history['total_loss'], color=colors[5], label='Total Loss')
    
    plt.title('Training Losses')
    plt.xlabel('Steps')
    plt.ylabel('Loss')
    plt.legend()
    
    # plt.grid(True)
    plt.show()
    
def print_logs(history, epoch, total_epochs, n_batch, step, gamma, delta, beta):
    print('------------Losses---------------')
    print('loss_reconstruction: ',  history['loss_reconstruction'][-1])
    print('loss_sobel: ',  history['loss_sobel'][-1])
    print('loss_dkl: ',  history['loss_dkl'][-1])
    print('loss_discriminator: ',  history['loss_discriminator'][-1])
    print('loss_gan: ',  history['loss_gan'][-1])
    print('total_loss: ',  history['total_loss'][-1])
    print('---------------------------------')
    print('------------Params---------------')
    print('Gamma: ', gamma)
    print('Delta: ', delta)
    print('Beta: ', beta)
    print('---------------------------------')
    print(f'Epoch: {epoch}/{total_epochs}')
    print(f'N Batch: {n_batch}')
    print(f'Step: {step}')
    
def plot_params(history, step):
    fig, axs = plt.subplots(1, 3, figsize=(20, 6))  # Correção na ordem de desempacotamento e ajuste no tamanho da figura para melhor visualização.
    
    axs[0].plot(history['gamma'], label='Gamma', color='#1AD59E')  # Correção na chamada de plot.
    axs[0].set_title('Gamma')  # Correção na configuração do título.
    axs[0].set_xlabel('Steps')  # Correção na configuração do rótulo do eixo x.
    axs[0].set_ylabel('Value')  # Correção na configuração do rótulo do eixo y.
    axs[0].legend()
    
    axs[1].plot(history['delta'], label='Delta', color='#417EB1')  # Ajustando a cor para vermelho e corrigindo a chamada de plot.
    axs[1].set_title('Delta')
    axs[1].set_xlabel('Steps')
    axs[1].set_ylabel('Value')
    axs[1].legend()
    
    axs[2].plot(history['beta'], label='Beta', color='#482790')  # Ajustando a cor para roxo e corrigindo a chamada de plot.
    axs[2].set_title('Beta')
    axs[2].set_xlabel('Steps')
    axs[2].set_ylabel('Value')
    axs[2].legend()
    
    plt.show()

# %%
dataset_train = ds_train.shuffle(1000).batch(32, drop_remainder=True).prefetch(1)
dataset_val = ds_val.shuffle(1000).batch(32, drop_remainder=True).prefetch(1)

# %%
def sobel_loss(X_input, X_reconstruction, gamma=32.0):
    # print(X_input.shape, X_reconstruction.shape)
    X_input, X_reconstruction = tf.cast(X_input, tf.float32), tf.cast(X_reconstruction, tf.float32)
    sobel = tf.image.sobel_edges(X_input)
    sobel_y = sobel[:, :, :, :, 0] # sobel in y-direction
    sobel_x = sobel[:, :, :, :, 1] # sobel in x-direction

    sobel_hat = tf.image.sobel_edges(X_reconstruction)
    sobel_y_hat = sobel_hat[:, :, :, :, 0] # sobel in y-direction
    sobel_x_hat = sobel_hat[:, :, :, :, 1] # sobel in x-direction
    
    gradient_input = sobel_x ** 2 + sobel_y ** 2
    
    gradient_reconstruction = sobel_x_hat ** 2 + sobel_y_hat ** 2
    
    return gamma * tf.reduce_mean(tf.abs(gradient_input - gradient_reconstruction)) / (128. * 128.)

# %%
variational_ae.compile()
discriminator.compile(loss='binary_crossentropy', optimizer='rmsprop')
discriminator.trainable = False
variational_encoder.trainable = False
gan.compile(loss='binary_crossentropy', optimizer='rmsprop')

# %%
def scheduler(start_param, end_param, n_steps, step):
    return np.clip(start_param + (end_param - start_param) * step / n_steps, start_param, end_param)

def train_gan(gan, variational_ae, dataset_train, batch_size, codings_size, n_epochs):
    step = 0
    history = {
            'loss_reconstruction': [],
            'loss_sobel': [],
            'loss_dkl': [],
            'loss_discriminator': [], 
            'loss_gan': [], 
            'total_loss': [],
            'gamma': [],
            'delta': [],
            'beta': [],
        }
    MSE = keras.losses.MeanSquaredError()
    delta = lambda step: scheduler(0.0, 1.5, 4_000, step)
    gamma = lambda step: scheduler(0.0, 512.0, 5_000, step)
    beta = lambda step: scheduler(0.0, 1.0, 40_000, step)
    SobelLoss = sobel_loss
    optimizer = keras.optimizers.RMSprop()
    step = 0
    generator, discriminator = gan.layers
    
    for epoch in tqdm(range(n_epochs)):
        n_batch = 0
        for X_batch_1 in tqdm(dataset_train):
            
            # -------------------------------------
            # Fase 0 - Treinar a rede VAE
            delta_value = delta(step)
            gamma_value = gamma(step)
            beta_value = beta(step)
            with tf.GradientTape() as tape:
                # Forward pass.
                X_reconstructions = variational_ae(X_batch_1)
                # New loss reconstruction
                detail = X_batch_1 - X_reconstructions
                X_batch_more_detail = np.clip(X_batch_1 + delta_value * detail, 0, 1)
                # Loss reconstruction
                loss_reconstruction = MSE(X_batch_more_detail, X_reconstructions)
                # Loss sobel
                loss_sobel = SobelLoss(X_batch_more_detail, X_reconstructions, gamma=gamma_value)
                # Loss KL Divergence
                loss_dkl = sum(variational_ae.losses) * beta_value
                # Add extra loss terms to the loss value.
                loss_total = loss_dkl + loss_reconstruction + loss_sobel
            
            gradients = tape.gradient(loss_total, variational_ae.trainable_weights)
            optimizer.apply_gradients(zip(gradients, variational_ae.trainable_weights))
            # -------------------------------------
            
            
            # -------------------------------------
            # Fase 1 - Treina a rede discriminator
            # noise = tf.random.normal(shape=[batch_size, codings_size])
            # _, _, noise = variational_encoder(X_batch)
            # generated_images = generator(noise)
            generated_images = variational_ae(X_batch_1)
            X_fake_and_real = tf.concat([generated_images, X_batch_1], axis=0)
            y1 = tf.constant([[0.]] * batch_size + [[1.]] * batch_size)
            history_discriminator = discriminator.train_on_batch(X_fake_and_real, y1, return_dict=True)
            # -------------------------------------
            
            # Fase 2 - Treina a rede generator - Lembre-se que para a GAN os parametros da discriminator estao congelados
            # noise = tf.random.normal(shape=[batch_size, codings_size])
            _, _, noise = variational_encoder(X_batch_1)
            y2 = tf.constant([[1.]] * batch_size)
            history_gan = gan.train_on_batch(noise, y2, return_dict=True)
            
            if step % 100 == 0:
            
                history['loss_reconstruction'].append(loss_reconstruction)
                history['loss_sobel'].append(loss_sobel)
                history['loss_dkl'].append(sum(variational_ae.losses))
                history['loss_discriminator'].append(history_discriminator['loss'])
                history['loss_gan'].append(history_gan['loss'])
                history['total_loss'].append(loss_total)
                history['gamma'].append(gamma_value)
                history['delta'].append(delta_value)
                history['beta'].append(beta_value)
        
                generated_images = variational_ae(X_batch_1)
                clear_output()
                plot_multiple_images(generated_images.numpy(), 8)
                plot_losses(history)
                plot_params(history, step)
                
                print_logs(history, epoch, n_epochs, n_batch, step, gamma_value, delta_value, beta_value)
                plt.show()    
            n_batch += 1
            step += 1

# %%
train_gan(gan, variational_ae, dataset_train, batch_size=32, codings_size=512, n_epochs=25)
# Out:
# ------------Losses---------------
# loss_reconstruction:  tf.Tensor(0.10663217, shape=(), dtype=float32)
# loss_sobel:  tf.Tensor(0.022189608, shape=(), dtype=float32)
# loss_dkl:  tf.Tensor(1.6078669, shape=(), dtype=float32)
# loss_discriminator:  4.314873458532986e-10
# loss_gan:  1.4397421921330533e-08
# total_loss:  tf.Tensor(0.61118186, shape=(), dtype=float32)
# ---------------------------------
# ------------Params---------------
# Gamma:  512.0
# Delta:  1.5
# Beta:  0.3
# ---------------------------------
# Epoch: 2/25
# N Batch: 1872
# Step: 12000
#  38%|███▊      | 1929/5064 [33:34<54:33,  1.04s/it]
#   8%|▊         | 2/25 [3:23:55<39:05:11, 6117.90s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22072\1794831512.py in <module>
# ----> 1 train_gan(gan, variational_ae, dataset_train, batch_size=32, codings_size=512, n_epochs=25)
#
# ~\AppData\Local\Temp\ipykernel_22072\2918711775.py in train_gan(gan, variational_ae, dataset_train, batch_size, codings_size, n_epochs)
#      48                 loss_total = loss_dkl + loss_reconstruction + loss_sobel
#      49
# ---> 50             gradients = tape.gradient(loss_total, variational_ae.trainable_weights)
#      51             optimizer.apply_gradients(zip(gradients, variational_ae.trainable_weights))
#      52             # -------------------------------------
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1111                           for x in output_gradients]
#    1112
# -> 1113     flat_grad = imperative_grad.imperative_grad(
#    1114         self._tape,
#    1115         flat_targets,
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\eager\imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     158       gradient_name_scope += forward_pass_name_scope + "/"
#     159     with ops.name_scope(gradient_name_scope):
# --> 160       return grad_fn(mock_op, *out_grads)
#     161   else:
#     162     return grad_fn(mock_op, *out_grads)
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py in _RealDivGrad(op, grad)
#    1460   x = math_ops.conj(x)
#    1461   y = math_ops.conj(y)
# -> 1462   return (array_ops.reshape(
#    1463       math_ops.reduce_sum(math_ops.realdiv(grad, y), rx), sx),
#    1464           array_ops.reshape(
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1174       # Fallback dispatch system (dispatch v1):
#    1175       try:
# -> 1176         return dispatch_target(*args, **kwargs)
#    1177       except (TypeError, ValueError):
#    1178         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py in reshape(tensor, shape, name)
#     197     A `Tensor`. Has the same type as `tensor`.
#     198   """
# --> 199   result = gen_array_ops.reshape(tensor, shape, name)
#     200   tensor_util.maybe_set_static_shape(result, shape)
#     201   return result
#
# c:\Users\gabri\anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in reshape(tensor, shape, name)
#    8535   if tld.is_eager:
#    8536     try:
# -> 8537       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    8538         _ctx, "Reshape", name, tensor, shape)
#    8539       return _result
#
# KeyboardInterrupt:

# %%
# variational_ae.save('resnet_celeba_vae_gan_with_sobel_loss/autoencoder/vae_autoencoder.tf')
# variational_encoder.save('resnet_celeba_vae_gan_with_sobel_loss/encoder/vae_encoder.tf')
# variational_decoder.save('resnet_celeba_vae_gan_with_sobel_loss/decoder/vae_decoder.tf')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, conv2d_1_layer_call_fn while saving (showing 5 of 76). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: resnet_celeba_vae/autoencoder/vae_autoencoder.tf\assets
# INFO:tensorflow:Assets written to: resnet_celeba_vae/autoencoder/vae_autoencoder.tf\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, conv2d_1_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, conv2d_2_layer_call_fn while saving (showing 5 of 46). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: resnet_celeba_vae/encoder/vae_encoder.tf\assets
# INFO:tensorflow:Assets written to: resnet_celeba_vae/encoder/vae_encoder.tf\assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, conv2d_70_layer_call_fn while saving (showing 5 of 30). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: resnet_celeba_vae/decoder/vae_decoder.tf\assets
# INFO:tensorflow:Assets written to: resnet_celeba_vae/decoder/vae_decoder.tf\assets
